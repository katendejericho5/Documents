# %% [markdown]
# # Data Cleaning Walkthrough (East African E‑Commerce Dataset)
#
# This notebook will walk you through the process of **cleaning and preparing a real-world dataset** step by step — beginner friendly.
#
# We will cover:
# 1. Loading and exploring the dataset
# 2. Renaming and standardizing columns
# 3. Handling missing values
# 4. Removing duplicates
# 5. Cleaning text, numbers, and dates
# 6. Detecting and handling outliers
# 7. Feature engineering
# 8. Exporting the cleaned dataset

# %%
# !pip install  pandas numpy matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in /home/jericho/Documents/venv/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: numpy in /home/jericho/Documents/venv/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /home/jericho/Documents/venv/lib/python3.12/site-packages (3.10.6)
# Requirement already satisfied: seaborn in /home/jericho/Documents/venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/jericho/Documents/venv/lib/python3.12/site-packages (1.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/jericho/Documents/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install Pillow --upgrade
# Out:
# Requirement already satisfied: Pillow in /home/jericho/Documents/venv/lib/python3.12/site-packages (11.3.0)

# %%
# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Display settings for pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
# Step 2: Load the dataset
file_path = "eastafrican-ecommerce-dataset.csv"
df = pd.read_csv(file_path, on_bad_lines="skip", engine="python")
print(f"Raw shape: {df.shape}  (rows, cols)")# Preview the first few rows
df.head()
# Out:
# Raw shape: (68, 12)  (rows, cols)
#   CustomerID FirstName LastName                   Email RegistrationDate  \
# 0    CUST001    david    Okello  david.okello@email.com       15/01/2022
# 1    CUST002    Esther  Wanjiku      esther.w@email.com       2022-02-20
# 2    CUST004    Fatuma     Juma    fatuma.juma@work.net       10/04/2022
# 3    CUST005     DAVID   OKELLO  david.okello@email.com       12/05/2022
# 4    CUST001    david    Okello  david.okello@email.com       15/01/2022
#
#     Country           City  TotalSpent Currency   Age   PhoneNumber  \
# 0    Uganda        Kampala      150000      UGX  34.0  2.567721e+11
# 1     Kenya        Nairobi        5500      KES  28.0  7.123457e+08
# 2  Tanzania  Dar es Salaam       80000      TZS  31.0  2.557551e+11
# 3        UG            Kla       75000      Shs  34.0  7.721235e+08
# 4    Uganda        Kampala      150000      UGX  34.0  2.567721e+11
#
#   LastLoginDate
# 0    20/08/2025
# 1    21/08/2025
# 2    15/07/2025
# 3           NaN
# 4    20/08/2025

# %%
# Step 3: Basic info and summary statistics
df.info()

df_fuzzy = df.copy()  # Create a copy for fuzzy matching later
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        68 non-null     object
#  1   FirstName         68 non-null     object
#  2   LastName          68 non-null     object
#  3   Email             67 non-null     object
#  4   RegistrationDate  68 non-null     object
#  5   Country           68 non-null     object
#  6   City              68 non-null     object
#  7   TotalSpent        68 non-null     int64
#  8   Currency          65 non-null     object
#  9   Age               67 non-null     float64
#  10  PhoneNumber       67 non-null     float64
#  11  LastLoginDate     35 non-null     object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 6.5+ KB

# %%
# Quick descriptive statistics for numerical columns
df.describe(include='all').transpose()
# Out:
#                  count unique                     top freq  \
# CustomerID          68     65                 CUST001    2
# FirstName           68     65                  david     2
# LastName            68     58                  Okello    2
# Email               67     63  david.okello@email.com    3
# RegistrationDate    68     22              15/01/2022    6
# Country             68      8                   Kenya   28
# City                68     16                 Nairobi   21
# TotalSpent        68.0    NaN                     NaN  NaN
# Currency            65      7                     KES   26
# Age               67.0    NaN                     NaN  NaN
# PhoneNumber       67.0    NaN                     NaN  NaN
# LastLoginDate       35      9              20/08/2025    6
#
#                                 mean                  std          min  \
# CustomerID                       NaN                  NaN          NaN
# FirstName                        NaN                  NaN          NaN
# LastName                         NaN                  NaN          NaN
# Email                            NaN                  NaN          NaN
# RegistrationDate                 NaN                  NaN          NaN
# Country                          NaN                  NaN          NaN
# City                             NaN                  NaN          NaN
# TotalSpent              92575.588235        213289.668546        180.0
# Currency                         NaN                  NaN          NaN
# Age                3743121283.880597    30638767858.47826         21.0
# PhoneNumber       61441248939.716415  109198027809.079636  701123456.0
# LastLoginDate                    NaN                  NaN          NaN
#
#                           25%          50%          75%             max
# CustomerID                NaN          NaN          NaN             NaN
# FirstName                 NaN          NaN          NaN             NaN
# LastName                  NaN          NaN          NaN             NaN
# Email                     NaN          NaN          NaN             NaN
# RegistrationDate          NaN          NaN          NaN             NaN
# Country                   NaN          NaN          NaN             NaN
# City                      NaN          NaN          NaN             NaN
# TotalSpent             6125.0      20000.0      95750.0       1250000.0
# Currency                  NaN          NaN          NaN             NaN
# Age                      29.0         34.0         40.0  250789123456.0
# PhoneNumber       722222222.0  754123456.0  788623456.0  256772123456.0
# LastLoginDate             NaN          NaN          NaN             NaN

# %% [markdown]
# Convert the RegistrationDate and LastLoginDate columns to a consistent datetime format, such as YYYY-MM-DD.

# %%
df[ ['LastLoginDate' ,'RegistrationDate']].head()
# Out:
#   LastLoginDate RegistrationDate
# 0    20/08/2025       15/01/2022
# 1    21/08/2025       2022-02-20
# 2    15/07/2025       10/04/2022
# 3           NaN       12/05/2022
# 4    20/08/2025       15/01/2022

# %%
df['RegistrationDate'] = pd.to_datetime(df['RegistrationDate'], dayfirst=True, errors='coerce')
df['LastLoginDate'] = pd.to_datetime(df['LastLoginDate'], dayfirst=True, errors='coerce')
df[ ['LastLoginDate' ,'RegistrationDate']].head()
# Out:
#   LastLoginDate RegistrationDate
# 0    2025-08-20       2022-01-15
# 1    2025-08-21              NaT
# 2    2025-07-15       2022-04-10
# 3           NaT       2022-05-12
# 4    2025-08-20       2022-01-15

# %% [markdown]
# Standardize Phone Number Format and Data Type

# %%
df['PhoneNumber'] = df['PhoneNumber'].astype(str).str.replace(r'\D', '', regex=True)

# Preview the standardized phone numbers
df[['PhoneNumber']].head()
# Out:
#      PhoneNumber
# 0  2567721234560
# 1     7123456780
# 2  2557551234560
# 3     7721234560
# 4  2567721234560

# %%
# Add '0' to PhoneNumber only if it starts with '7', ignore others
df['PhoneNumber'] = df['PhoneNumber'].apply(lambda x: '0' + x if x.startswith('7') else x)

# Preview the standardized phone numbers
df[['PhoneNumber']].head()
# Out:
#      PhoneNumber
# 0  2567721234560
# 1    07123456780
# 2  2557551234560
# 3    07721234560
# 4  2567721234560

# %%
df.head()
# Out:
#   CustomerID FirstName LastName                   Email RegistrationDate  \
# 0    CUST001    david    Okello  david.okello@email.com       2022-01-15
# 1    CUST002    Esther  Wanjiku      esther.w@email.com              NaT
# 2    CUST004    Fatuma     Juma    fatuma.juma@work.net       2022-04-10
# 3    CUST005     DAVID   OKELLO  david.okello@email.com       2022-05-12
# 4    CUST001    david    Okello  david.okello@email.com       2022-01-15
#
#     Country           City  TotalSpent Currency   Age    PhoneNumber  \
# 0    Uganda        Kampala      150000      UGX  34.0  2567721234560
# 1     Kenya        Nairobi        5500      KES  28.0    07123456780
# 2  Tanzania  Dar es Salaam       80000      TZS  31.0  2557551234560
# 3        UG            Kla       75000      Shs  34.0    07721234560
# 4    Uganda        Kampala      150000      UGX  34.0  2567721234560
#
#   LastLoginDate
# 0    2025-08-20
# 1    2025-08-21
# 2    2025-07-15
# 3           NaT
# 4    2025-08-20

# %% [markdown]
# NEXT WE NEED TO ENSURE CONSISTTENCY IN THE COUNTRY AND CITY FIELDS

# %%
print("\nUnique values in 'City' column:")
df['City'].unique()
# Out:
# Unique values in 'City' column:
# array(['Kampala', 'Nairobi', 'Dar es Salaam', 'Kla', 'Entebbe', 'Niarobi',
#        'Kmapala', 'Nrb', 'Mbarara', 'Kigali', 'Gulu', 'Kisumu', 'Arusha',
#        'Eldoret', 'Mombasa', 'Jinja'], dtype=object)

# %%
print("Unique values in 'Country' column:")

df['Country'].unique()
# Out:
# Unique values in 'Country' column:
# array(['Uganda', 'Kenya', 'Tanzania', 'UG', 'KE', 'uganda', 'Rwanda',
#        'UGANDA'], dtype=object)

# %%
# Create mapping dictionaries based on our discovery
country_mapping = {'ug': 'Uganda', 'ke': 'Kenya', 'UGANDA': 'Uganda'}
city_mapping = {'kla': 'Kampala', 'nrb': 'Nairobi', 'niarobi': 'Nairobi', 'kmapala': 'Kampala'}

# Apply the mapping to the relevant columns
df['Country'] = df['Country'].replace(country_mapping)
df['City'] = df['City'].replace(city_mapping)

# Standardize the casing for uniformity
df['Country'] = df['Country'].str.title()
df['City'] = df['City'].str.title()
df['FirstName'] = df['FirstName'].str.title()
df['LastName'] = df['LastName'].str.title()

# %%
print("Unique values in 'Country' column:")

df['Country'].unique()
# Out:
# Unique values in 'Country' column:
# array(['Uganda', 'Kenya', 'Tanzania', 'Ug', 'Ke', 'Rwanda'], dtype=object)

# %%
print("\nUnique values in 'City' column:")
df['City'].unique()
# Out:
# Unique values in 'City' column:
# array(['Kampala', 'Nairobi', 'Dar Es Salaam', 'Kla', 'Entebbe', 'Niarobi',
#        'Kmapala', 'Nrb', 'Mbarara', 'Kigali', 'Gulu', 'Kisumu', 'Arusha',
#        'Eldoret', 'Mombasa', 'Jinja'], dtype=object)

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /home/jericho/Documents/venv/lib/python3.12/site-packages (0.18.0)

# %%
import pandas as pd
from fuzzywuzzy import process
from io import StringIO



# Standardize casing first to improve matching accuracy
df_fuzzy['City'] = df_fuzzy['City'].str.title().str.strip()

# A list of our known, correct city names for matching
correct_cities = ['Kampala', 'Nairobi', 'Kigali', 'Dar Es Salaam', 'Entebbe']

print("--- Step 1: Unique Cities BEFORE Fuzzy Matching ---")
print(df_fuzzy['City'].unique())

def fuzzy_match_and_correct(city_name, correct_list):
    """
    Finds the best fuzzy match for a city name from a list of correct names.
    Returns the corrected city name if the match score is high (>= 80).
    """
    if pd.isna(city_name):
        return city_name
    
    best_match = process.extractOne(city_name, correct_list)
    
    # Print the matching process to demonstrate the logic
    print(f"Processing '{city_name}': Best match is '{best_match[0]}' with score {best_match[1]}")
    
    if best_match[1] >= 80: # Check if the score is 80 or higher
        return best_match[0] # Return the best match name
    else:
        return city_name # Return original name if no good match is found
# Out:
# --- Step 1: Unique Cities BEFORE Fuzzy Matching ---
# ['Kampala' 'Nairobi' 'Dar Es Salaam' 'Kla' 'Entebbe' 'Niarobi' 'Kmapala'
#  'Nrb' 'Mbarara' 'Kigali' 'Gulu' 'Kisumu' 'Arusha' 'Eldoret' 'Mombasa'
#  'Jinja']
# /home/jericho/Documents/venv/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
print("\n--- Step 2: Running Fuzzy Match Process ---")
# Apply the fuzzy matching function to the 'City' column
df_fuzzy['City'] = df_fuzzy['City'].apply(lambda x: fuzzy_match_and_correct(x, correct_cities))
# Out:
# --- Step 2: Running Fuzzy Match Process ---
# Processing 'Kampala': Best match is 'Kampala' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Kla': Best match is 'Kampala' with score 60
# Processing 'Kampala': Best match is 'Kampala' with score 100
# Processing 'Entebbe': Best match is 'Entebbe' with score 100
# Processing 'Niarobi': Best match is 'Nairobi' with score 86
# Processing 'Kmapala': Best match is 'Kampala' with score 86
# Processing 'Nrb': Best match is 'Nairobi' with score 60
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Mbarara': Best match is 'Kampala' with score 43
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Kigali': Best match is 'Kigali' with score 100
# Processing 'Gulu': Best match is 'Kigali' with score 45
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Kisumu': Best match is 'Kigali' with score 33
# Processing 'Kampala': Best match is 'Kampala' with score 100
# Processing 'Kla': Best match is 'Kampala' with score 60
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Kmapala': Best match is 'Kampala' with score 86
# Processing 'Nrb': Best match is 'Nairobi' with score 60
# Processing 'Arusha': Best match is 'Dar Es Salaam' with score 45
# Processing 'Eldoret': Best match is 'Entebbe' with score 29
# Processing 'Kigali': Best match is 'Kigali' with score 100
# Processing 'Mombasa': Best match is 'Kampala' with score 43
# Processing 'Kampala': Best match is 'Kampala' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Kisumu': Best match is 'Kigali' with score 33
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Jinja': Best match is 'Kigali' with score 36
# Processing 'Kisumu': Best match is 'Kigali' with score 33
# Processing 'Kla': Best match is 'Kampala' with score 60
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Mombasa': Best match is 'Kampala' with score 43
# Processing 'Kmapala': Best match is 'Kampala' with score 86
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Kigali': Best match is 'Kigali' with score 100
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Kampala': Best match is 'Kampala' with score 100
# Processing 'Jinja': Best match is 'Kigali' with score 36
# Processing 'Mbarara': Best match is 'Kampala' with score 43
# Processing 'Gulu': Best match is 'Kigali' with score 45
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Gulu': Best match is 'Kigali' with score 45
# Processing 'Eldoret': Best match is 'Entebbe' with score 29
# Processing 'Dar Es Salaam': Best match is 'Dar Es Salaam' with score 100
# Processing 'Kisumu': Best match is 'Kigali' with score 33
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Arusha': Best match is 'Dar Es Salaam' with score 45
# Processing 'Kigali': Best match is 'Kigali' with score 100
# Processing 'Kmapala': Best match is 'Kampala' with score 86
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Nairobi': Best match is 'Nairobi' with score 100
# Processing 'Kla': Best match is 'Kampala' with score 60
# Processing 'Kisumu': Best match is 'Kigali' with score 33
# Processing 'Eldoret': Best match is 'Entebbe' with score 29
# Processing 'Nairobi': Best match is 'Nairobi' with score 100

# %%
print("\n--- Step 3: Unique Cities AFTER Fuzzy Matching ---")
df_fuzzy['City'].unique()
# Out:
# --- Step 3: Unique Cities AFTER Fuzzy Matching ---
# array(['Kampala', 'Nairobi', 'Dar Es Salaam', 'Kla', 'Entebbe', 'Nrb',
#        'Mbarara', 'Kigali', 'Gulu', 'Kisumu', 'Arusha', 'Eldoret',
#        'Mombasa', 'Jinja'], dtype=object)

# %% [markdown]
# ### Step 5: Handling Missing Values
# - We check how many missing values exist.
# - Then decide: drop, fill, or keep them.

# %%
# Check missing values
df.isnull().sum()
# Out:
# CustomerID           0
# FirstName            0
# LastName             0
# Email                1
# RegistrationDate     2
# Country              0
# City                 0
# TotalSpent           0
# Currency             3
# Age                  1
# PhoneNumber          0
# LastLoginDate       33
# dtype: int64

# %%
df.dropna(subset=['Email'], inplace=True)

# %%
for col in df.select_dtypes(include=[np.number]).columns:
    df[col].fillna(df[col].median(), inplace=True)

for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipykernel_28435/1957888083.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /tmp/ipykernel_28435/1957888083.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /tmp/ipykernel_28435/1957888083.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna("Unknown", inplace=True)

# %% [markdown]
# ### Step 6: Remove Duplicates

# %%
# Drop duplicate rows if any
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (64, 12)

# %% [markdown]
# ### Step 7: Cleaning Text, Numbers, and Dates
# - Strip extra spaces
# - Standardize casing
# - Parse dates correctly

# %%
# Example: strip spaces and lowercase for string columns
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip().str.lower()

# %%
# Convert potential date columns
for col in df.columns:
    if "date" in col:
        df[col] = pd.to_datetime(df[col], errors='coerce')

df.head()
# Out:
#   CustomerID FirstName LastName                   Email RegistrationDate  \
# 0    cust001     david   okello  david.okello@email.com       2022-01-15
# 1    cust002    esther  wanjiku      esther.w@email.com              NaT
# 2    cust004    fatuma     juma    fatuma.juma@work.net       2022-04-10
# 3    cust005     david   okello  david.okello@email.com       2022-05-12
# 6    cust007      john  ochieng       john.ochieng@mail              NaT
#
#     Country           City  TotalSpent Currency   Age    PhoneNumber  \
# 0    uganda        kampala      150000      ugx  34.0  2567721234560
# 1     kenya        nairobi        5500      kes  28.0    07123456780
# 2  tanzania  dar es salaam       80000      tzs  31.0  2557551234560
# 3        ug            kla       75000      shs  34.0    07721234560
# 6        ke        niarobi        2500      ksh  50.0  2547221234560
#
#   LastLoginDate
# 0    2025-08-20
# 1    2025-08-21
# 2    2025-07-15
# 3           NaT
# 6           NaT

# %% [markdown]
# ### Step 8: Outlier Detection and Handling
# We’ll visualize numerical columns with boxplots to check for extreme outliers.

# %%
result = df[df['Age'] >= 120][['FirstName', 'LastName', 'Age']].copy()
result['Age'] = result['Age'].astype(int)
print(result)
# Out:
#    FirstName LastName           Age
# 7        bob     kato           150
# 12     grace   mutesi  250789123456
# 40      eric  sentamu           250

# %%
age_above_100 = df[df['Age'] > 100]


df[df['Age'] >= 100]
# Out:
#    CustomerID FirstName LastName             Email RegistrationDate Country  \
# 7     cust009       bob     kato     bob@email.com       2023-05-15  uganda
# 12    cust016     grace   mutesi  grace.m@mail.com       2024-12-01  rwanda
# 40    cust059      eric  sentamu    eric@email.com       2023-05-15  uganda
#
#        City  TotalSpent Currency           Age    PhoneNumber LastLoginDate
# 7   kmapala       95000      ugx  1.500000e+02  2567521234560    2025-08-18
# 12   kigali       40000       -5  2.507891e+11                          NaT
# 40  kmapala       99000      ugx  2.500000e+02    07561234560    2025-08-18

# %%
print("--- Initial DataFrame showing missing 'Age' ---")
print(df)

# Impute missing Age values with the median age

age_median = df['Age'].median()
df['Age'].fillna(age_median, inplace=True)

print("\n--- After Imputing Missing Age with the Median ---")
print(df)
print("\nDataFrame Info (after imputing age):")
df.info()

# This creates a new column to indicate if the Age was missing.
df['Age_missing'] = df['Age'].isna().astype(int)
# Out:
# --- Initial DataFrame showing missing 'Age' ---
#    CustomerID FirstName    LastName                   Email RegistrationDate  \
# 0     cust001     david      okello  david.okello@email.com       2022-01-15
# 1     cust002    esther     wanjiku      esther.w@email.com              NaT
# 2     cust004    fatuma        juma    fatuma.juma@work.net       2022-04-10
# 3     cust005     david      okello  david.okello@email.com       2022-05-12
# 6     cust007      john     ochieng       john.ochieng@mail              NaT
# ..        ...       ...         ...                     ...              ...
# 63    cust092     nancy       mumbi           nancy.m@email       2023-08-11
# 64    cust093   stanley        kato     stanley.k@email.com       2023-09-14
# 65    cust094      rose      akinyi        rose.a@email.com       2024-10-30
# 66    cust096    hellen  chepkwemoi       hellen.c@mail.com       2024-12-01
# 67    cust098    vivian     wachira                vivian.w       2025-02-25
#
#      Country           City  TotalSpent Currency   Age    PhoneNumber  \
# 0     uganda        kampala      150000      ugx  34.0  2567721234560
# 1      kenya        nairobi        5500      kes  28.0    07123456780
# 2   tanzania  dar es salaam       80000      tzs  31.0  2557551234560
# 3         ug            kla       75000      shs  34.0    07721234560
# 6         ke        niarobi        2500      ksh  50.0  2547221234560
# ..       ...            ...         ...      ...   ...            ...
# 63     kenya        nairobi        5900      kes  24.0    07311234560
# 64    uganda            kla       81000  unknown  29.0    07821234560
# 65     kenya         kisumu        4400      kes  32.0    07081234560
# 66     kenya        eldoret        3900      ksh  29.0    07111234560
# 67     kenya        nairobi        7100      kes  38.0    07261234560
#
#    LastLoginDate
# 0     2025-08-20
# 1     2025-08-21
# 2     2025-07-15
# 3            NaT
# 6            NaT
# ..           ...
# 63    2025-08-24
# 64           NaT
# 65    2025-08-23
# 66    2025-08-22
# 67    2025-08-21
#
# [64 rows x 12 columns]
#
# --- After Imputing Missing Age with the Median ---
#    CustomerID FirstName    LastName                   Email RegistrationDate  \
# 0     cust001     david      okello  david.okello@email.com       2022-01-15
# 1     cust002    esther     wanjiku      esther.w@email.com              NaT
# 2     cust004    fatuma        juma    fatuma.juma@work.net       2022-04-10
# 3     cust005     david      okello  david.okello@email.com       2022-05-12
# 6     cust007      john     ochieng       john.ochieng@mail              NaT
# ..        ...       ...         ...                     ...              ...
# 63    cust092     nancy       mumbi           nancy.m@email       2023-08-11
# 64    cust093   stanley        kato     stanley.k@email.com       2023-09-14
# 65    cust094      rose      akinyi        rose.a@email.com       2024-10-30
# 66    cust096    hellen  chepkwemoi       hellen.c@mail.com       2024-12-01
# 67    cust098    vivian     wachira                vivian.w       2025-02-25
#
#      Country           City  TotalSpent Currency   Age    PhoneNumber  \
# 0     uganda        kampala      150000      ugx  34.0  2567721234560
# 1      kenya        nairobi        5500      kes  28.0    07123456780
# 2   tanzania  dar es salaam       80000      tzs  31.0  2557551234560
# 3         ug            kla       75000      shs  34.0    07721234560
# 6         ke        niarobi        2500      ksh  50.0  2547221234560
# ..       ...            ...         ...      ...   ...            ...
# 63     kenya        nairobi        5900      kes  24.0    07311234560
# 64    uganda            kla       81000  unknown  29.0    07821234560
# 65     kenya         kisumu        4400      kes  32.0    07081234560
# 66     kenya        eldoret        3900      ksh  29.0    07111234560
# 67     kenya        nairobi        7100      kes  38.0    07261234560
#
#    LastLoginDate
# 0     2025-08-20
# 1     2025-08-21
# 2     2025-07-15
# 3            NaT
# 6            NaT
# ..           ...
# 63    2025-08-24
# 64           NaT
# 65    2025-08-23
# 66    2025-08-22
# 67    2025-08-21
#
# [64 rows x 12 columns]
#
# DataFrame Info (after imputing age):
# <class 'pandas.core.frame.DataFrame'>
# Index: 64 entries, 0 to 67
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        64 non-null     object
#  1   FirstName         64 non-null     object
#  2   LastName          64 non-null     object
#  3   Email             64 non-null     object
#  4   RegistrationDate  62 non-null     datetime64[ns]
#  5   Country           64 non-null     object
#  6   City              64 non-null     object
#  7   TotalSpent        64 non-null     int64
#  8   Currency          64 non-null     object
#  9   Age               64 non-null     float64
#  10  PhoneNumber       64 non-null     object
#  11  LastLoginDate     32 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(8)
# memory usage: 6.5+ KB
# /tmp/ipykernel_28435/1049123966.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(age_median, inplace=True)

# %%
# Example: Cap outliers at 1st and 99th percentile
for col in df.select_dtypes(include=[np.number]).columns:
    lower, upper = df[col].quantile([0.01, 0.99])
    df[col] = np.clip(df[col], lower, upper)

# %% [markdown]
# ### Step 9: Feature Engineering
# Let’s create some useful new features, e.g.:
# - `order_month` from `order_date`
# - `is_high_value_order` if price > threshold

# %%
if "order_date" in df.columns:
    df['order_month'] = df['order_date'].dt.to_period('M')

if "price" in df.columns:
    df['is_high_value_order'] = df['price'] > df['price'].median()

df.head()
# Out:
#   CustomerID FirstName LastName                   Email RegistrationDate  \
# 0    cust001     david   okello  david.okello@email.com       2022-01-15
# 1    cust002    esther  wanjiku      esther.w@email.com              NaT
# 2    cust004    fatuma     juma    fatuma.juma@work.net       2022-04-10
# 3    cust005     david   okello  david.okello@email.com       2022-05-12
# 6    cust007      john  ochieng       john.ochieng@mail              NaT
#
#     Country           City  TotalSpent Currency   Age    PhoneNumber  \
# 0    uganda        kampala    150000.0      ugx  34.0  2567721234560
# 1     kenya        nairobi      5500.0      kes  28.0    07123456780
# 2  tanzania  dar es salaam     80000.0      tzs  31.0  2557551234560
# 3        ug            kla     75000.0      shs  34.0    07721234560
# 6        ke        niarobi      2500.0      ksh  50.0  2547221234560
#
#   LastLoginDate  Age_missing
# 0    2025-08-20            0
# 1    2025-08-21            0
# 2    2025-07-15            0
# 3           NaT            0
# 6           NaT            0

# %% [markdown]
# ### Step 10: Export Cleaned Dataset
# Now that cleaning is complete, let’s save the cleaned file.

# %%
output_file = "eastafrican-ecommerce-dataset.cleaned.csv"
df.to_csv(output_file, index=False)
print(f"Cleaned dataset saved as {output_file}")
# Out:
# Cleaned dataset saved as eastafrican-ecommerce-dataset.cleaned.csv
